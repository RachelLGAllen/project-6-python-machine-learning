# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/rachelallen/CareerFoundry Achievement 6/02 Original Data'

# %%
df = pd.read_pickle(os.path.join(path, '02 cleaned data', 'shanghai_barrolee_GDP.pkl'))

# %%
df.head()
# Out:
#   world_rank     university_name national_rank  total_score  alumni  award  \
# 0          1  Harvard University             1        100.0   100.0  100.0
# 1          1  Harvard University             1        100.0   100.0  100.0
# 2          1  Harvard University             1        100.0   100.0  100.0
# 3          1  Harvard University             1        100.0   100.0  100.0
# 4          1  Harvard University             1        100.0   100.0  100.0
#
#    highly_cited  nature_science_pub  papers_cited  weighted_score  ...  2012  \
# 0         100.0               100.0         100.0            72.4  ...   NaN
# 1         100.0               100.0         100.0            73.6  ...   NaN
# 2         100.0               100.0         100.0            73.0  ...   NaN
# 3         100.0               100.0         100.0            74.1  ...   NaN
# 4         100.0               100.0         100.0            74.8  ...   NaN
#
#   2013 2014 2015  2016  2017 2018  2019  2020  2021
# ...

# %%
df.shape
# Out:
# (480081, 89)

# %%
# export as csv so I can try and make it excel

df.to_csv(os.path.join(path, '02 cleaned data', 'shanghai_barrolee_gdp.csv'))
