# %%
#import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/rachelallen/CareerFoundry Achievement 6/02 Original Data'

# %%
df_cwurdata = pd.read_csv(os.path.join(path, 'all raw data', 'cwurData.csv'), index_col = False)

# %%
#examine data

df_cwurdata.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df_cwurdata.shape
# Out:
# (2200, 14)

# %%
df_cwurdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %%
df_cwurdata.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')

# %%
df_cwurdata.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
#import next df

df_shanghai = pd.read_csv(os.path.join(path, 'all raw data', 'shanghaiData.csv'), index_col = False)

# %%
df_shanghai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
df_shanghai.shape
# Out:
# (4897, 11)

# %%
df_shanghai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4897 entries, 0 to 4896
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   world_rank       4897 non-null   object
#  1   university_name  4896 non-null   object
#  2   national_rank    4896 non-null   object
#  3   total_score      1101 non-null   float64
#  4   alumni           4896 non-null   float64
#  5   award            4895 non-null   float64
#  6   hici             4895 non-null   float64
#  7   ns               4875 non-null   float64
#  8   pub              4895 non-null   float64
#  9   pcp              4895 non-null   float64
#  10  year             4897 non-null   int64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 421.0+ KB

# %%
df_shanghai.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year'],
#       dtype='object')

# %%
df_shanghai.describe()
# Out:
#        total_score       alumni       award         hici           ns  \
# count  1101.000000  4896.000000  4895.00000  4895.000000  4875.000000
# mean     36.383470     9.161724     7.69191    16.221491    16.078503
# std      13.557186    14.140636    15.49411    14.382710    12.511529
# min      23.500000     0.000000     0.00000     0.000000     0.000000
# 25%      27.400000     0.000000     0.00000     7.300000     8.000000
# 50%      31.300000     0.000000     0.00000    12.600000    12.800000
# 75%      41.800000    15.600000    13.40000    21.700000    19.800000
# max     100.000000   100.000000   100.00000   100.000000   100.000000
#
#                pub          pcp         year
# count  4895.000000  4895.000000  4897.000000
# mean     38.254648    21.242329  2009.658566
# std      13.050809     9.254351     3.197576
# min       7.300000     8.300000  2005.000000
# 25%      28.900000    15.600000  2007.000000
# 50%      36.000000    19.000000  2009.000000
# ...

# %%
#import timesData as df_times

df_times = pd.read_csv(os.path.join(path, 'all raw data', 'timesData.csv'), index_col = False)

# %%
#examine data

df_times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
df_times.shape
# Out:
# (2603, 14)

# %%
df_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  student_staff_ratio     2544 non-null   float64
#  11  international_students  2536 non-null   object
#  12  female_male_ratio       2370 non-null   object
#  13  year                    2603 non-null   int64
# ...

# %%
df_times.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')

# %%
df_times.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %%
#import school_and_country_table as df_sac

df_sac = pd.read_csv(os.path.join(path, 'all raw data', 'school_and_country_table.csv'), index_col = False)

# %%
df_sac.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %%
df_sac.shape
# Out:
# (818, 2)

# %%
df_sac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  818 non-null    object
#  1   country      818 non-null    object
# dtypes: object(2)
# memory usage: 12.9+ KB

# %%
df_sac.describe()
# Out:
#                school_name                   country
# count                  818                       818
# unique                 818                        70
# top     Harvard University  United States of America
# freq                     1                       161

# %%
df_sac['country'].value_counts(dropna = False)
# Out:
# United States of America    161
# United Kingdom               78
# Japan                        41
# Germany                      39
# China                        38
#                            ...
# Luxembourg                    1
# Morocco                       1
# Macau                         1
# Iceland                       1
# Lithuania                     1
# Name: country, Length: 70, dtype: int64

# %%
#definitely will need to merge this table with the others to have geographic info

# %%
#import educational_attainment_supplementary_data.csv as df_easd

df_easd = pd.read_csv(os.path.join(path, 'all raw data', 'educational_attainment_supplementary_data.csv'))

# %%
df_easd.head()
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# ...

# %%
df_easd.shape
# Out:
# (79055, 29)

# %%
df_easd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79055 entries, 0 to 79054
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  79052 non-null  object
#  1   series_name   79050 non-null  object
#  2   1985          51843 non-null  float64
#  3   1986          12 non-null     float64
#  4   1987          3 non-null      float64
#  5   1990          51846 non-null  float64
#  6   1991          1 non-null      float64
#  7   1992          3 non-null      float64
#  8   1993          1 non-null      float64
#  9   1995          51884 non-null  float64
#  10  1996          3 non-null      float64
#  11  1997          0 non-null      float64
#  12  1998          47 non-null     float64
#  13  1999          9 non-null      float64
#  14  2000          51970 non-null  float64
#  15  2001          225 non-null    float64
#  16  2002          184 non-null    float64
# ...

# %%
df_easd.describe()
# Out:
#                 1985       1986      1987           1990     1991      1992  \
# count   51843.000000  12.000000  3.000000   51846.000000  1.00000  3.000000
# mean      253.059289   6.365242  1.988220     280.061650  7.58463  5.758003
# std      5812.705429   2.335996  0.883044    6525.945102      NaN  0.244010
# min         0.000000   3.740600  1.118970       0.000000  7.58463  5.514150
# 25%         1.020000   4.841200  1.540110       1.230000  7.58463  5.635920
# 50%         5.070000   5.581280  1.961250       5.670000  7.58463  5.757690
# 75%        23.245000   7.255653  2.422845      24.100000  7.58463  5.879930
# max    745898.000000  10.192880  2.884440  835430.000000  7.58463  6.002170
#
#           1993           1995     1996  1997  ...          2005        2006  \
# count  1.00000   51884.000000  3.00000   0.0  ...  5.203700e+04  204.000000
# mean   6.22103     306.774826  7.79931   NaN  ...  3.635199e+02   13.172861
# ...

# %%
df_easd['country_name'].value_counts(dropna = False)
# Out:
# Afghanistan                                                       425
# Papua New Guinea                                                  425
# New Caledonia                                                     425
# New Zealand                                                       425
# Nicaragua                                                         425
#                                                                  ...
# Greece                                                            425
# Guatemala                                                         425
# NaN                                                                 3
# Data from database: Education Statistics: Education Attainment      1
# Last Updated: 10/20/2015                                            1
# Name: country_name, Length: 189, dtype: int64

# %%
df_easd['series_name'].value_counts(dropna = False)
# Out:
# Barro-Lee: Average years of primary schooling, age 15+, female                                                               186
# Barro-Lee: Percentage of population age 50-54 with secondary schooling. Total (Incomplete and Completed Secondary)           186
# Barro-Lee: Percentage of population age 50-54 with primary schooling. Total (Incomplete and Completed Primary)               186
# Barro-Lee: Percentage of population age 50-54 with primary schooling. Completed Primary                                      186
# Barro-Lee: Percentage of population age 50-54 with no education                                                              186
#                                                                                                                             ...
# Barro-Lee: Percentage of female population age 20-24 with tertiary schooling. Completed Tertiary                             186
# ...

# %%
# this column is really interesting but ngl I'm not sure how to interpret it

# %%
#import education_expenditure_supplementary_data as df_eesd

df_eesd = pd.read_csv(os.path.join(path, 'all raw data', 'education_expenditure_supplementary_data.csv'), lineterminator='\n')

# %%
df_eesd.head()
# Out:
# Empty DataFrame
# Columns: [country, institute_type, direct_expenditure_type, 1995, 2000, 2005, 2009, 2010, 2011
# OECD Average, All Institutions , Public, 4.9, 4.9.1, 5.0, 5.4, 5.4.1, 5.3
# Australia, All Institutions .1, Public.1, 4.5, 4.6, 4.3, 4.5.1, 4.6.1, 4.3
# Austria, All Institutions .2, Public.2, 5.3, 5.4.2, 5.2, 5.7, 5.6, 5.5
# Belgium, All Institutions .3, Public.3, 5.0.1, 5.1, 5.8, 6.4, 6.4.1, 6.4
# Canada, All Institutions .4, Public.4, 5.8.1, 5.2.1, 4.8, 5.0.2, 5.2.2,
# Chile, All Institutions .5, Public.5, Unnamed: 51, 4.2, 3.3, 4.1, 4.3.1, 3.9
# Czech Republic, All Institutions .6, Public.6, 4.8.1, 4.2.1, 4.1.1, 4.2.2, 4.1.2, 4.4
# Denmark, All Institutions .7, Public.7, 6.5, 6.4.2, 6.8, 7.5, 7.6, 7.5
# Estonia, All Institutions .8, Public.8, Unnamed: 75, Unnamed: 76, 4.7, 5.9, 5.6.1, 5.2
# Finland, All Institutions .9, Public.9, 6.6, 5.5, 5.9.1, 6.3, 6.4.3, 6.3
# France, All Institutions .10, Public.10, 5.8.2, 5.7.1, 5.6.2, 5.8.3, 5.8.4, 5.6
# ...

# %% [markdown]
# ### I got a very strange error when I tried to import this file and went to stack overflow to try and figure it out -- they suggested adding the lineterminator='\n' at the end, which did allow me to import it, but now the file says it has zero rows

# %%
#

df_expend = pd.read_csv(os.path.join(path, 'all raw data', 'tabn605.20.csv'))

# %%
df_expend.head(20)
# Out:
#    Table 605.20. Public and private direct expenditures on education institutions as a percentage of gross domestic product, by level of education and country: Selected years, 1995 through 2011  \
# 0                                             Country
# 1                                                 NaN
# 2                                                 NaN
# 3                                                  1
# 4      OECD average\2\ ..............................
# 5                          Australia ................
# 6                             Austria ...............
# 7                       Belgium .....................
# 8                            Canada .................
# 9                           Chile ...................
# 10                                                NaN
# 11                 Czech Republic ...................
# 12                       Denmark ....................
# 13                          Estonia .................
# ...

# %% [markdown]
# ### Okay I found the data but it looks like garbage in python and it looks okay in excel, I will need to reformat it or something at some point

# %%
#examining some other datasets from the World Bank 

#

df_expend = pd.read_csv(os.path.join(path, 'all raw data', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353', 'Metadata_Country_API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353.csv'))

# %%
df_expend.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
#

df_expend2 = pd.read_csv(os.path.join(path, 'all raw data', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353', 'Metadata_Indicator_API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353.csv'))

# %%
df_expend2.head()
# Out:
#    INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  SE.XPD.TERT.ZS  Expenditure on tertiary education (% of govern...
#
#                                          SOURCE_NOTE  \
# 0  Expenditure on tertiary education is expressed...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  UNESCO Institute for Statistics (http://uis.un...         NaN

# %%
df_expend3 = pd.read_csv(os.path.join(path, 'all raw data', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353.csv'))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/sg/643_lsvj2pj89g1m5qn18t800000gp/T/ipykernel_4744/3975616457.py in <module>
# ----> 1 df_expend3 = pd.read_csv(os.path.join(path, 'all raw data', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353', 'API_SE.XPD.TERT.ZS_DS2_en_csv_v2_4354353.csv'))
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_expend3.head()
# Out:
#                                                    0
# 0        Data Source,"World Development Indicators",
# 1                  "Last Updated Date","2022-07-20",
# 2  "Country Name","Country Code","Indicator Name"...
# 3  "Aruba","ABW","Expenditure on tertiary educati...
# 4  "Africa Eastern and Southern","AFE","Expenditu...

# %% [markdown]
# ### I opened the file in excel and saw it had four rows above the header row, so I deleted those and saved it as a new name and exported that as a .csv file which I was then able to open in Jupyter

# %%
df_tertiary = pd.read_csv(os.path.join(path, 'all raw data', 'expenditure_tertiary.csv'))

# %%
df_tertiary.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Expenditure on tertiary education (% of govern...  SE.XPD.TERT.ZS   NaN
# 1  Expenditure on tertiary education (% of govern...  SE.XPD.TERT.ZS   NaN
# 2  Expenditure on tertiary education (% of govern...  SE.XPD.TERT.ZS   NaN
# 3  Expenditure on tertiary education (% of govern...  SE.XPD.TERT.ZS   NaN
# 4  Expenditure on tertiary education (% of govern...  SE.XPD.TERT.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014      2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  21.672690  20.021530  25.09833
# 1   NaN   NaN   NaN   NaN   NaN  ...  17.566855        NaN       NaN
# ...

# %%
# I did the same thing for the other two files -- opened them in excel to delete the first blank rows and then opened them here to examine them

df_gdp = pd.read_csv(os.path.join(path, 'all raw data', 'expenditure_percent_gdp.csv'), index_col = False)

# %%
df_gdp.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...      2013      2014      2015      2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  6.442960  5.851280  5.888270  5.491350
# ...

# %%
df_govt_spent = pd.read_csv(os.path.join(path, 'all raw data', 'expenditure_as_percent_total_govt_expenditure.csv'), index_col = False)

# %%
df_govt_spent.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 1  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 2  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 3  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  21.877630  19.617979  23.201380
# 1   NaN   NaN   NaN   NaN   NaN  ...  17.243259  18.097099  16.962910
# ...

# %%
df_barrolee = pd.read_csv(os.path.join(path, 'all raw data', 'BL2013_MF_v2.2.csv'), index_col = False)

# %%
df_barrolee.head(25
            )
# Out:
#     BLcode  country  year sex  agefrom  ageto     lu     lp   lpc    ls   lsc  \
# 0        1  Algeria  1950  MF       15     19  86.12  13.32  3.64  0.54  0.12
# 1        1  Algeria  1950  MF       20     24  81.48  16.22  4.30  1.90  0.75
# 2        1  Algeria  1950  MF       25     29  81.48  16.22  4.30  1.90  0.75
# 3        1  Algeria  1950  MF       30     34  81.20  16.80  3.50  1.60  0.52
# 4        1  Algeria  1950  MF       35     39  81.20  16.80  3.50  1.60  0.51
# 5        1  Algeria  1950  MF       40     44  78.90  19.10  3.20  1.70  0.53
# 6        1  Algeria  1950  MF       45     49  78.90  19.10  3.20  1.70  0.52
# 7        1  Algeria  1950  MF       50     54  77.68  20.62  3.20  1.40  0.42
# 8        1  Algeria  1950  MF       55     59  77.68  20.62  3.20  1.40  0.41
# 9        1  Algeria  1950  MF       60     64  75.00  23.40  2.90  1.30  0.39
# 10       1  Algeria  1950  MF       65     69  75.11  23.43  2.90  1.18  0.34
# ...

# %%
df_barrolee.shape
# Out:
# (28470, 20)

# %%
df_barrolee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28470 entries, 0 to 28469
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   BLcode       28470 non-null  int64
#  1   country      28470 non-null  object
#  2   year         28470 non-null  int64
#  3   sex          28470 non-null  object
#  4   agefrom      28470 non-null  int64
#  5   ageto        28470 non-null  int64
#  6   lu           28470 non-null  float64
#  7   lp           28470 non-null  float64
#  8   lpc          28470 non-null  float64
#  9   ls           28470 non-null  float64
#  10  lsc          28470 non-null  float64
#  11  lh           28470 non-null  float64
#  12  lhc          28470 non-null  float64
#  13  yr_sch       28470 non-null  float64
#  14  yr_sch_pri   28470 non-null  float64
#  15  yr_sch_sec   28470 non-null  float64
#  16  yr_sch_ter   28470 non-null  float64
#  17  pop          28470 non-null  float64
# ...

# %%
df_barrolee2 = pd.read_csv(os.path.join(path, 'all raw data', 'BL2013_MF1599_v2.2.csv'), index_col = False)

# %%
df_barrolee2.head(20)
# Out:
#     BLcode  country  year sex  agefrom  ageto     lu     lp    lpc     ls  \
# 0        1  Algeria  1950  MF       15    999  80.68  17.56   3.75   1.45
# 1        1  Algeria  1955  MF       15    999  81.05  17.02   3.46   1.64
# 2        1  Algeria  1960  MF       15    999  82.61  14.31   3.07   2.75
# 3        1  Algeria  1965  MF       15    999  80.93  14.42   4.01   4.21
# 4        1  Algeria  1970  MF       15    999  73.64  19.22   5.23   6.69
# 5        1  Algeria  1975  MF       15    999  64.45  25.24   4.26   9.57
# 6        1  Algeria  1980  MF       15    999  55.76  29.51   4.59  13.20
# 7        1  Algeria  1985  MF       15    999  45.78  33.12  13.02  18.56
# 8        1  Algeria  1990  MF       15    999  38.88  35.21  14.74  22.21
# 9        1  Algeria  1995  MF       15    999  32.89  37.97  19.34  24.43
# 10       1  Algeria  2000  MF       15    999  28.17  43.22  24.04  22.35
# 11       1  Algeria  2005  MF       15    999  29.60  43.93  27.20  19.63
# ...

# %%
df_barrolee3 = pd.read_csv(os.path.join(path, 'all raw data', 'BL2013_MF2599_v2.2.csv'), index_col = False)

# %%
df_barrolee3.head(20)
# Out:
#     BLcode  country  year sex  agefrom  ageto     lu     lp    lpc     ls  \
# 0        1  Algeria  1950  MF       25    999  79.20  18.88   3.55   1.58
# 1        1  Algeria  1955  MF       25    999  79.80  18.10   3.60   1.70
# 2        1  Algeria  1960  MF       25    999  84.56  13.51   2.82   1.60
# 3        1  Algeria  1965  MF       25    999  88.00   9.80   2.43   1.70
# 4        1  Algeria  1970  MF       25    999  84.40  13.00   3.17   2.20
# 5        1  Algeria  1975  MF       25    999  78.51  16.54   3.15   4.52
# 6        1  Algeria  1980  MF       25    999  70.38  21.88   3.91   6.85
# 7        1  Algeria  1985  MF       25    999  61.37  27.38   8.80   9.36
# 8        1  Algeria  1990  MF       25    999  52.01  31.93  11.75  12.87
# 9        1  Algeria  1995  MF       25    999  44.24  35.21  14.12  15.94
# 10       1  Algeria  2000  MF       25    999  38.36  37.54  17.48  18.22
# 11       1  Algeria  2005  MF       25    999  35.60  40.25  22.44  16.50
# ...
