# %% [markdown]
# ## Table of Contents
#
# ### 1. Import libraries and data to practice with
#
# ### 2. data exploration and practicing the techniques in 6.2
#
# ### 3. merged dataframes
#
# ### 4. repeated the data exploration and visualizations from 6.2 with the merged dataset

# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#check matplotlib version

matplotlib.__version__
# Out:
# '3.4.3'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
#define path

path = r'/Users/rachelallen/CareerFoundry Achievement 6'

# %%
#import data to practice with

df = pd.read_csv(os.path.join(path, '02 Original Data', '02 cleaned data', 'shanghaiData.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0 world_rank                              university_name  \
# 0           0          1                           Harvard University
# 1           1          2                      University of Cambridge
# 2           2          3                          Stanford University
# 3           3          4           University of California, Berkeley
# 4           4          5  Massachusetts Institute of Technology (MIT)
#
#   national_rank  total_score  alumni  award  highly_cited  nature_science_pub  \
# 0             1        100.0   100.0  100.0         100.0               100.0
# 1             1         73.6    99.8   93.4          53.3                56.6
# 2             2         73.4    41.1   72.2          88.5                70.9
# 3             3         72.8    71.8   76.0          69.4                73.9
# 4             4         70.1    74.0   80.6          66.7                65.8
#
#    papers_cited  weighted_score  year
# ...

# %%
#I need to merge this dataframe with other data in order for this to work, but this will be okay for practicing

df.corr()
# Out:
#                     Unnamed: 0  total_score    alumni     award  highly_cited  \
# Unnamed: 0            1.000000    -0.026274 -0.047206  0.006549     -0.013698
# total_score          -0.026274     1.000000  0.769191  0.831950      0.870980
# alumni               -0.047206     0.769191  1.000000  0.763562      0.620527
# award                 0.006549     0.831950  0.763562  1.000000      0.669609
# highly_cited         -0.013698     0.870980  0.620527  0.669609      1.000000
# nature_science_pub   -0.016077     0.929130  0.694470  0.735800      0.868726
# papers_cited          0.030002     0.627578  0.516182  0.468816      0.674076
# weighted_score       -0.004981     0.755265  0.672102  0.729365      0.690232
# year                  0.989707    -0.009685  0.008245  0.059676      0.052731
#
#                     nature_science_pub  papers_cited  weighted_score      year
# Unnamed: 0                   -0.016077      0.030002       -0.004981  0.989707
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Save figure
plt.matshow(df.corr())
plt.savefig("df_practice_heat.png") 

# This will save the image in the working directory.

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# '/Users/rachelallen/CareerFoundry Achievement 6/03 Scripts'

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#whoops Im going to drop that unnamed column

df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 world_rank                              university_name  \
# 0              0          1                           Harvard University
# 1              1          2                      University of Cambridge
# 2              2          3                          Stanford University
# 3              3          4           University of California, Berkeley
# 4              4          5  Massachusetts Institute of Technology (MIT)
# ...          ...        ...                                          ...
# 4892        4892    401-500                        University of Trieste
# 4893        4893    401-500                       University of Zaragoza
# 4894        4894    401-500                        Utah State University
# 4895        4895    401-500              Vienna University of Technology
# 4896        4896    401-500                       Wake Forest University
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'world_rank', 'university_name', 'national_rank',
#        'total_score', 'alumni', 'award', 'highly_cited', 'nature_science_pub',
#        'papers_cited', 'weighted_score', 'year'],
#       dtype='object')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award  highly_cited  nature_science_pub  papers_cited  \
# 0        100.0   100.0  100.0         100.0               100.0         100.0
# 1         73.6    99.8   93.4          53.3                56.6          70.9
# 2         73.4    41.1   72.2          88.5                70.9          72.3
# 3         72.8    71.8   76.0          69.4                73.9          72.2
# 4         70.1    74.0   80.6          66.7                65.8          64.3
#
#    weighted_score  year
# 0            72.4  2005
# ...

# %%
df.corr()
# Out:
#                     total_score    alumni     award  highly_cited  \
# total_score            1.000000  0.769191  0.831950      0.870980
# alumni                 0.769191  1.000000  0.763562      0.620527
# award                  0.831950  0.763562  1.000000      0.669609
# highly_cited           0.870980  0.620527  0.669609      1.000000
# nature_science_pub     0.929130  0.694470  0.735800      0.868726
# papers_cited           0.627578  0.516182  0.468816      0.674076
# weighted_score         0.755265  0.672102  0.729365      0.690232
# year                  -0.009685  0.008245  0.059676      0.052731
#
#                     nature_science_pub  papers_cited  weighted_score      year
# total_score                   0.929130      0.627578        0.755265 -0.009685
# alumni                        0.694470      0.516182        0.672102  0.008245
# award                         0.735800      0.468816        0.729365  0.059676
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(11, 11)) # figure size 
plt.matshow(df.corr(), fignum=f.number) # type of plot
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(df.shape[1]), df.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### Using Seaborn

# %%
df.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
#        'weighted_score', 'year'],
#       dtype='object')

# %%
#exclude non numeric columns -- names and also year

sub = df[['world_rank', 'national_rank', 'total_score', 'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited', 'weighted_score']]

# %%
sub.head()
# Out:
#   world_rank national_rank  total_score  alumni  award  highly_cited  \
# 0          1             1        100.0   100.0  100.0         100.0
# 1          2             1         73.6    99.8   93.4          53.3
# 2          3             2         73.4    41.1   72.2          88.5
# 3          4             3         72.8    71.8   76.0          69.4
# 4          5             4         70.1    74.0   80.6          66.7
#
#    nature_science_pub  papers_cited  weighted_score
# 0               100.0         100.0            72.4
# 1                56.6          70.9            66.9
# 2                70.9          72.3            65.0
# 3                73.9          72.2            52.7
# 4                65.8          64.3            53.0

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ### scatterplots

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = 'nature_science_pub', y = 'total_score', data = df)

# %% [markdown]
# ### pair plots

# %%
#keep only the variables you want to use for pair plots

sub_2 = df[['total_score', 'nature_science_pub', 'highly_cited', 'award']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)

# %% [markdown]
# ### the histograms didn't REALLY work out???

# %% [markdown]
# ### categorical plots

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the price ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['total_score'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='total_score', ylabel='Count'>

# %%
df.loc[df['total_score'] < 35, 'Score category'] = 'Low score'

# %%
df.loc[(df['total_score'] >= 35) & (df['total_score'] <75), 'Score category'] = 'Middle score'

# %%
df.loc[df['total_score'] >= 75, 'Score category'] = 'High score'

# %%
df['Score category'].value_counts(dropna = False)
# Out:
# NaN             3796
# Low score        701
# Middle score     389
# High score        11
# Name: Score category, dtype: int64

# %%
df['total_score'].value_counts(dropna = False)
# Out:
# NaN     3796
# 24.9      17
# 25.5      15
# 29.5      13
# 24.6      13
#         ...
# 64.8       1
# 69.5       1
# 71.0       1
# 73.1       1
# 70.2       1
# Name: total_score, Length: 338, dtype: int64

# %%
df.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
#        'weighted_score', 'year', 'Score category'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="nature_science_pub", y="highly_cited", hue="Score category", data=df)

# %%
#that took upwards of 30 minutes to run, so just be aware of that!

# %%
df.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award  highly_cited  nature_science_pub  papers_cited  \
# 0        100.0   100.0  100.0         100.0               100.0         100.0
# 1         73.6    99.8   93.4          53.3                56.6          70.9
# 2         73.4    41.1   72.2          88.5                70.9          72.3
# 3         72.8    71.8   76.0          69.4                73.9          72.2
# 4         70.1    74.0   80.6          66.7                65.8          64.3
#
#    weighted_score  year Score category
# ...

# %%
#import data to practice with

country = pd.read_csv(os.path.join(path, '02 Original Data', '02 cleaned data', 'school_country_table.csv'))

# %%
country.head()
# Out:
#    Unnamed: 0                            school_name                   country
# 0           0                     Harvard University  United States of America
# 1           1     California Institute of Technology  United States of America
# 2           2  Massachusetts Institute of Technology  United States of America
# 3           3                    Stanford University  United States of America
# 4           4                   Princeton University  United States of America

# %%
#drop unnamed column
country = country.drop(columns = ['Unnamed: 0'])

# %% [raw]
# country.head()

# %%
country.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %%
#rename school_name as university_name

country.rename(columns={"school_name": "university_name"})
# Out:
#                            university_name                   country
# 0                       Harvard University  United States of America
# 1       California Institute of Technology  United States of America
# 2    Massachusetts Institute of Technology  United States of America
# 3                      Stanford University  United States of America
# 4                     Princeton University  United States of America
# ..                                     ...                       ...
# 813                      Xidian University                     China
# 814                    Yeungnam University               South Korea
# 815            Yıldız Technical University                    Turkey
# 816               Yokohama City University                     Japan
# 817           Yokohama National University                     Japan
#
# [818 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
#        'weighted_score', 'year', 'Score category'],
#       dtype='object')

# %%
country.columns
# Out:
# Index(['school_name', 'country'], dtype='object')

# %%
country = country.rename(columns={"school_name": "university_name"})

# %%
country.columns
# Out:
# Index(['university_name', 'country'], dtype='object')

# %%
pd.merge(df,country, on = ['university_name'], indicator = True)
# Out:
#      world_rank                      university_name national_rank  \
# 0             1                   Harvard University             1
# 1             1                   Harvard University             1
# 2             1                   Harvard University             1
# 3             1                   Harvard University             1
# 4             1                   Harvard University             1
# ...         ...                                  ...           ...
# 3009    401-500           Capital Medical University         28-32
# 3010    401-500  Queensland University of Technology            20
# 3011    401-500      Sharif University of Technology             2
# 3012    401-500                  University of Genoa         11-20
# 3013    401-500                University of Seville          9-13
#
#       total_score  alumni  award  highly_cited  nature_science_pub  \
# 0           100.0   100.0  100.0         100.0               100.0
# ...

# %%
pd
# Out:
# <module 'pandas' from '/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
df_merged = df.merge(country, on = ['university_name'], indicator = True)

# %%
df_merged.head()
# Out:
#   world_rank     university_name national_rank  total_score  alumni  award  \
# 0          1  Harvard University             1        100.0   100.0  100.0
# 1          1  Harvard University             1        100.0   100.0  100.0
# 2          1  Harvard University             1        100.0   100.0  100.0
# 3          1  Harvard University             1        100.0   100.0  100.0
# 4          1  Harvard University             1        100.0   100.0  100.0
#
#    highly_cited  nature_science_pub  papers_cited  weighted_score  year  \
# 0         100.0               100.0         100.0            72.4  2005
# 1         100.0               100.0         100.0            73.6  2006
# 2         100.0               100.0         100.0            73.0  2007
# 3         100.0               100.0         100.0            74.1  2008
# 4         100.0               100.0         100.0            74.8  2009
#
#   Score category                   country _merge
# ...

# %%
df_merged['_merge'].value_counts(dropna = False)
# Out:
# both          3014
# left_only        0
# right_only       0
# Name: _merge, dtype: int64

# %%
df_merged.shape
# Out:
# (3014, 14)

# %%
df.shape
# Out:
# (4897, 12)

# %%
country.shape
# Out:
# (818, 2)

# %%
#uh oh we lost rows when we did that, we need an outer join 

df_merged2 = df.merge(country, on = ['university_name'], indicator = True, how = 'outer')

# %%
df_merged2.head()
# Out:
#   world_rank     university_name national_rank  total_score  alumni  award  \
# 0          1  Harvard University             1        100.0   100.0  100.0
# 1          1  Harvard University             1        100.0   100.0  100.0
# 2          1  Harvard University             1        100.0   100.0  100.0
# 3          1  Harvard University             1        100.0   100.0  100.0
# 4          1  Harvard University             1        100.0   100.0  100.0
#
#    highly_cited  nature_science_pub  papers_cited  weighted_score    year  \
# 0         100.0               100.0         100.0            72.4  2005.0
# 1         100.0               100.0         100.0            73.6  2006.0
# 2         100.0               100.0         100.0            73.0  2007.0
# 3         100.0               100.0         100.0            74.1  2008.0
# 4         100.0               100.0         100.0            74.8  2009.0
#
#   Score category                   country _merge
# ...

# %%
df_merged2.shape
# Out:
# (5331, 14)

# %%
df_merged2['_merge'].value_counts(dropna = False)
# Out:
# both          3014
# left_only     1883
# right_only     434
# Name: _merge, dtype: int64

# %%
#that fixed it, good job me

# %%
#import data to practice with

bl = pd.read_csv(os.path.join(path, '02 Original Data', '02 cleaned data', 'Barro_Lee_Cleaned.csv'))

# %%
bl.head()
# Out:
#    Unnamed: 0  BLcode  country  year sex  agefrom  ageto  no_school  some_pri  \
# 0           0       1  Algeria  1950  MF       15     19      86.12     13.32
# 1           1       1  Algeria  1950  MF       20     24      81.48     16.22
# 2           2       1  Algeria  1950  MF       25     29      81.48     16.22
# 3           3       1  Algeria  1950  MF       30     34      81.20     16.80
# 4           4       1  Algeria  1950  MF       35     39      81.20     16.80
#
#    complete_pri  ...  complete_sec  some_tert  complete_tert  yr_sch  \
# 0          3.64  ...          0.12       0.02           0.00    0.57
# 1          4.30  ...          0.75       0.40           0.16    0.89
# 2          4.30  ...          0.75       0.40           0.25    0.89
# 3          3.50  ...          0.52       0.40           0.25    0.85
# 4          3.50  ...          0.51       0.40           0.28    0.85
#
#    yr_sch_pri  yr_sch_sec  yr_sch_ter    pop  WBcode  \
# ...

# %%
#drop unnamed column
bl = bl.drop(columns = ['Unnamed: 0'])

# %%
bl.head()
# Out:
#    BLcode  country  year sex  agefrom  ageto  no_school  some_pri  \
# 0       1  Algeria  1950  MF       15     19      86.12     13.32
# 1       1  Algeria  1950  MF       20     24      81.48     16.22
# 2       1  Algeria  1950  MF       25     29      81.48     16.22
# 3       1  Algeria  1950  MF       30     34      81.20     16.80
# 4       1  Algeria  1950  MF       35     39      81.20     16.80
#
#    complete_pri  some_sec  complete_sec  some_tert  complete_tert  yr_sch  \
# 0          3.64      0.54          0.12       0.02           0.00    0.57
# 1          4.30      1.90          0.75       0.40           0.16    0.89
# 2          4.30      1.90          0.75       0.40           0.25    0.89
# 3          3.50      1.60          0.52       0.40           0.25    0.85
# 4          3.50      1.60          0.51       0.40           0.28    0.85
#
#    yr_sch_pri  yr_sch_sec  yr_sch_ter    pop WBcode  \
# 0        0.54        0.03        0.00  876.0    DZA
# ...

# %%
df_merged3 = df_merged2.merge(bl, on = ['country'], indicator = 'flag', how = 'outer')

# %%
df_merged3.head()
# Out:
#   world_rank     university_name national_rank  total_score  alumni  award  \
# 0          1  Harvard University             1        100.0   100.0  100.0
# 1          1  Harvard University             1        100.0   100.0  100.0
# 2          1  Harvard University             1        100.0   100.0  100.0
# 3          1  Harvard University             1        100.0   100.0  100.0
# 4          1  Harvard University             1        100.0   100.0  100.0
#
#    highly_cited  nature_science_pub  papers_cited  weighted_score  ...  \
# 0         100.0               100.0         100.0            72.4  ...
# 1         100.0               100.0         100.0            73.6  ...
# 2         100.0               100.0         100.0            73.0  ...
# 3         100.0               100.0         100.0            74.1  ...
# 4         100.0               100.0         100.0            74.8  ...
#
#    some_tert complete_tert yr_sch yr_sch_pri  yr_sch_sec  yr_sch_ter pop  \
# ...

# %%
df_merged3['flag'].value_counts(dropna = False)
# Out:
# both          460200
# right_only     16770
# left_only       2971
# Name: flag, dtype: int64

# %%
df_merged3.shape
# Out:
# (479941, 34)

# %%
#export combined and cleaned df

df_merged3.to_pickle(os.path.join(path, '02 Original Data', '02 cleaned data', 'shanghai_barrolee.pkl'))

# %% [markdown]
# ## Exercises for 6.2 start here

# %%
df_merged3.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
#        'weighted_score', 'year_x', 'Score category', 'country', '_merge',
#        'BLcode', 'year_y', 'sex', 'agefrom', 'ageto', 'no_school', 'some_pri',
#        'complete_pri', 'some_sec', 'complete_sec', 'some_tert',
#        'complete_tert', 'yr_sch', 'yr_sch_pri', 'yr_sch_sec', 'yr_sch_ter',
#        'pop', 'WBcode', 'region_code', 'flag'],
#       dtype='object')

# %%
df_merged3.corr()
# Out:
#                      total_score        alumni         award  highly_cited  \
# total_score         1.000000e+00  8.577401e-01  8.331309e-01  8.754432e-01
# alumni              8.577401e-01  1.000000e+00  7.199324e-01  5.772082e-01
# award               8.331309e-01  7.199324e-01  1.000000e+00  6.178229e-01
# highly_cited        8.754432e-01  5.772082e-01  6.178229e-01  1.000000e+00
# nature_science_pub  9.217557e-01  6.658061e-01  6.704315e-01  7.564280e-01
# papers_cited        6.343518e-01  4.467234e-01  4.113744e-01  5.497159e-01
# weighted_score      8.063473e-01  6.391308e-01  6.617472e-01  7.167202e-01
# year_x             -1.082897e-02 -1.335504e-02  3.798052e-02  7.265064e-02
# BLcode             -2.583661e-02  7.626003e-02  1.101226e-01  5.436692e-04
# year_y              3.833350e-14  2.631279e-14  1.803482e-14 -2.666925e-14
# agefrom             7.587148e-15  2.496123e-15  3.896769e-15  6.885644e-15
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(df_merged3.corr())
plt.show()

# %%
# Save figure
plt.matshow(df_merged3.corr())
plt.savefig("df_merged3_heat.png")

# %% [markdown]
# ### 2. Use the questions you defined in the previous task to pick out variables from your data set suitable for your exploratory visual analysis.

# %%
# Create a subset of columns

sub = df_merged3[['total_score', 'national_rank', 'agefrom', 'ageto','world_rank', 'complete_sec']]

# %%
sub.head()
# Out:
#    total_score national_rank  agefrom  ageto world_rank  complete_sec
# 0        100.0             1      NaN    NaN          1           NaN
# 1        100.0             1      NaN    NaN          1           NaN
# 2        100.0             1      NaN    NaN          1           NaN
# 3        100.0             1      NaN    NaN          1           NaN
# 4        100.0             1      NaN    NaN          1           NaN

# %% [markdown]
# ### 3.  Create a correlation matrix heatmap (colored).

# %%
plt.matshow(sub.corr())
plt.show()

# %%
# this subset is too small, I'm going to make a bigger one

sub2 = df_merged3[['world_rank', 'national_rank', 'total_score',
       'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
       'weighted_score', 'Score category', 'sex', 'agefrom', 'ageto', 'no_school', 'some_pri',
       'complete_pri', 'some_sec', 'complete_sec', 'some_tert',
       'complete_tert', 'yr_sch', 'yr_sch_pri', 'yr_sch_sec', 'yr_sch_ter',
       'pop']]

# %%
plt.matshow(sub2.corr())
plt.show()

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(8, 8)) # figure size 
plt.matshow(sub2.corr(), fignum=f.number) # type of plot
plt.xticks(range(sub2.shape[1]), sub2.columns, fontsize=14, rotation=45) # x axis labels
plt.yticks(range(sub2.shape[1]), sub2.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# #### It's pretty hard to read this even with the labels right on the chart, you can see a 1:1 correlation down the middle which we can ignore, and you can see that some things (top left and bottom right) have a much higher corrolation than other things, but in this format it's pretty hard to undrstand

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub2.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# #### This is a little better but if I make it larger it would be easier to read

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(15,15))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub2.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# #### strongest correlations look like total_score to alumni, highly_cited and nature_science_pub which makes sense, those are how the Shanghai Data made its scores. Complete_sec (completed secondary school )has a medium correlation to going on to tertiary school.

# %% [markdown]
# #### The darkest colors here mean a negative correlation and the lightest colors mean a positive correlation, where it seems like one thing might cause the other

# %% [markdown]
# ### 4. Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships.

# %%
# Create a scatterplot for the "total score" and "alumni" columns in seaborn

sns.lmplot(x = 'total_score', y = 'alumni', data = df_merged3)

# %% [markdown]
# #### there's a pretty clear positive correlation between the university's total score and the number of alumni who have won awards. However there are lots of numbers, especially at zero, and several outliers, especially that one up at the top

# %%
# Create a scatterplot for the "complete_sec" and "some_tert" columns in seaborn

sns.lmplot(x = 'complete_sec', y = 'some_tert', data = df_merged3)

# %% [markdown]
# #### This is certainly a scatterplot! There is a line of best fit through the scatterplot but nearly everything is an outlier and this just tells us that whie thre is some kind of correlation, you definitely can't say that one of these variables depends on the other

# %% [markdown]
# #### what this really tells me is I probably need to merge another of my dataframes to this dataframe to get more variables I can look at (government spending) against university and school success. For today I'm practicing, though.

# %% [markdown]
# ## Create a pair plot of the entire data set.
#
# ### Comment on the distribution of the variables and mark variables you’d like to explore further with an explanation of why.

# %%
# Keep only the variables you want to use in the pair plot

sub3 = df_merged3[['total_score', 'alumni', 'complete_sec', 'some_tert']]

# %%
# Create a pair plot 

g = sns.pairplot(sub3)

# %% [markdown]
# #### The scatterplots are definitely interesting, but even more interestingly the histograms barely exist, although you can see that most of them cluster closer to the y axis
#
# #### I want to look at total score and compare it to some of the data in other dfs I downloaded

# %% [markdown]
# ## 6 Create a categorical plot and interpret the results.

# %%
sns.histplot(df_merged3['total_score'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='total_score', ylabel='Count'>

# %% [markdown]
# #### most schools score below a 30, with very very few outliers scoring above a 75. To split these scores categorically I'm going to say < 30 "low score", 30 < 60 "medium score" and > 60 "high score"

# %%
df_merged3.loc[df_merged3['total_score'] < 30, 'score category'] = 'low score'

# %%
df_merged3.loc[(df_merged3['total_score'] >= 30) & (df_merged3['total_score'] < 75), 'score category'] = 'medium score'

# %%
df_merged3.loc[df_merged3['total_score'] >= 75, 'score category'] = 'high score'

# %%
df_merged3['score category'].value_counts(dropna = False)
# Out:
# NaN             415984
# low score        41588
# medium score     22358
# high score          11
# Name: score category, dtype: int64

# %%
# There are tons of na scores, and I should figure out how to do this while dropping the, probably

# %%
drop_na_version = df_merged3.dropna(subset=['score category'])

# %%
drop_na_version.shape
# Out:
# (63957, 35)

# %%
drop_na_version['score category'].value_counts(dropna = False)
# Out:
# low score       41588
# medium score    22358
# high score         11
# Name: score category, dtype: int64

# %%
drop_na_version.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'highly_cited', 'nature_science_pub', 'papers_cited',
#        'weighted_score', 'year_x', 'Score category', 'country', '_merge',
#        'BLcode', 'year_y', 'sex', 'agefrom', 'ageto', 'no_school', 'some_pri',
#        'complete_pri', 'some_sec', 'complete_sec', 'some_tert',
#        'complete_tert', 'yr_sch', 'yr_sch_pri', 'yr_sch_sec', 'yr_sch_ter',
#        'pop', 'WBcode', 'region_code', 'flag', 'score category'],
#       dtype='object')

# %%
#create df of only columns I'm going to use since this took half an hour last time I tried it

small = drop_na_version[['total_score', 'alumni', 'complete_sec', 'some_tert', 'score category', 'nature_science_pub']]

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="alumni", y="nature_science_pub", hue="score category", data=small)
